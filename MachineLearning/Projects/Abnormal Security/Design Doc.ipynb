# %% [markdown]
# ## Design Doc

# %%
from IPython.display import Image
Image(filename='DesignDoc.png')
# using the Abnormal Securities Generic Template, we will fill each criteria out.

# %% [markdown]
# # 1) Identify Question or Problem
# We know our Question is to classify whether the URLs are Spam or not
# However, here we also need to understand the problem space better:
# - Where is the data coming from?
# - What is the type of the data (i.e stored in a database, coming from raw emails, etc)
# - Do we want to classify just the URL or the contents which are entailed inside of the URL
# - Who or what will this problem's solution benefit? Does solving this problem align with the companies overall goals?

# %% [markdown]
# # 2) Experiment Design
#
# Here we will preform EDA, or data exploration, experimentation, failure, and changing design along the way when data has been collected. <br>
# We will need to choose a "tech stack" which aligns / works well with rest of our code base. <br>
# For example, if our data is stored in an AWS server, we can use AWS Cloud 9 for coding, and AWS for deployment later aswell. <br>
# Here, it might also be useful to think of also think of the computing resources we will need, and the good with having cloud based solutions such as with AWS, we can get higher computing if needed.

# %% [markdown]
# # 3) Software Design
#
# The way we write our code is important for many reasons, but most importantly for scalability, security, efficiency and being able to improve through an iterative process.
# Due to these reasons, we will need to decide on which data structures and design patterns to use, think about scalibility, storage, and time complexity.

# %% [markdown]
# # 4) Analyzing Data and Implementing Software
# Here we will pre-process the data, preform feature engineering, deal with class imbalance issues, explore feature encoding techniques for our dataset. <br>
# Since there is a vast amount of uniqueness for our text columns, for example, the domain or domain extensions, we will have to go beyond just one-hot-encoding or label encoding. <br>
# Perhaps some form of nlp ngrams -> tokenization / word embedding to grasp what the text is saying but in numbers.
#
# We will have to implement this with the technologies and patterns we decided in section 2 and 3.

# %% [markdown]
# # 5) Analyze Data and Train Models
# Train different kinds of models, tune hyperparameters, take the best 2-5 models and preform an ensemble of them to lower the false positive rates as much as possible.
# Keep track of some baseline model to compare to, and we can use metrics such as F1 score, precision / Recall, confusion matrix etc to evaluate our models.

# %% [markdown]
# # 6) Publish Results & Test Deploy and Monitor
